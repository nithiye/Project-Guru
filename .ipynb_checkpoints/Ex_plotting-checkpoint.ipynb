# %%
#%matplotlib notebook

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter, AutoMinorLocator)
from collections import OrderedDict
import matplotlib as mpl

# %%
# Read file with plotting information
plot_data_csv = "Output/Data_for_plotting.csv"

# Read data into Pandas data frames
plot_data_df = pd.read_csv(plot_data_csv)

# %%
# Add Totals for migrants
plot_data_df["Tot Migrant"] = plot_data_df.iloc[:,3:7].sum(axis=1)

# Add Totals for Indicators
plot_data_df["Tot Indic"] = plot_data_df.iloc[:,8:12].sum(axis=1)
plot_data_df
# Out:
#                   Origin        Dev Level         Income Range    2005_x  \
# 0            Afghanistan  Least developed           Low-income   3826255
# 1            Afghanistan  Least developed           Low-income   3826255
# 2             Bangladesh  Least developed  Lower-middle-income   5765158
# 3             Bangladesh  Least developed  Lower-middle-income   5765158
# 4                  China   Less Developed  Upper-middle-income   7242306
# 5                  China   Less Developed  Upper-middle-income   7242306
# 6                Germany   More Developed          High-income   3585342
# 7                Germany   More Developed          High-income   3585342
# 8                  India   Less Developed  Lower-middle-income   9649626
# 9                  India   Less Developed  Lower-middle-income   9649626
# 10             Indonesia   Less Developed  Lower-middle-income   2714351
# 11             Indonesia   Less Developed  Lower-middle-income   2714351
# 12                 Italy   More Developed          High-income   2739747
# 13                 Italy   More Developed          High-income   2739747
# 14            Kazakhstan   Less Developed  Upper-middle-income   3718926
# 15            Kazakhstan   Less Developed  Upper-middle-income   3718926
# 16                Mexico   Less Developed  Upper-middle-income  10816544
# 17                Mexico   Less Developed  Upper-middle-income  10816544
# 18              Pakistan   Less Developed  Lower-middle-income   3896494
# 19              Pakistan   Less Developed  Lower-middle-income   3896494
# 20           Philippines   Less Developed  Lower-middle-income   3700591
# 21           Philippines   Less Developed  Lower-middle-income   3700591
# 22                Poland   More Developed          High-income   2907295
# 23                Poland   More Developed          High-income   2907295
# 24               Romania   More Developed  Upper-middle-income   2106961
# 25               Romania   More Developed  Upper-middle-income   2106961
# 26    Russian Federation   More Developed  Upper-middle-income  10385025
# 27    Russian Federation   More Developed  Upper-middle-income  10385025
# 28  Syrian Arab Republic   Less Developed  Lower-middle-income    861759
# 29  Syrian Arab Republic   Less Developed  Lower-middle-income    861759
# 30                Turkey   Less Developed  Upper-middle-income   2693172
# 31                Turkey   Less Developed  Upper-middle-income   2693172
# 32               Ukraine   More Developed  Lower-middle-income   5567494
# 33               Ukraine   More Developed  Lower-middle-income   5567494
# 34        United Kingdom   More Developed          High-income   4140641
# 35        United Kingdom   More Developed          High-income   4140641
#
#       2010_x    2015_x    2017_x  \
# 0    4989209   4855376   4826464
# 1    4989209   4855376   4826464
# 2    6742845   7246726   7499919
# 3    6742845   7246726   7499919
# 4    8648435   9674720   9961559
# 5    8648435   9674720   9961559
# 6    3849980   4032528   4207957
# 7    3849980   4032528   4207957
# 8   13320745  15859419  16587070
# 9   13320745  15859419  16587070
# 10   3486338   3974691   4233788
# 11   3486338   3974691   4233788
# 12   2612391   2872011   3029145
# 13   2612391   2872011   3029145
# 14   3811293   3905768   4074446
# 15   3811293   3905768   4074446
# 16  12413073  12546524  12964869
# 17  12413073  12546524  12964869
# 18   5006753   5922305   5978635
# 19   5006753   5922305   5978635
# 20   4704919   5423323   5680682
# 21   4704919   5423323   5680682
# 22   3855177   4258157   4701465
# 23   3855177   4258157   4701465
# 24   3274229   3412055   3578504
# 25   3274229   3412055   3578504
# 26  10213313  10354892  10635994
# 27  10213313  10354892  10635994
# 28   1079749   6238472   6864445
# 29   1079749   6238472   6864445
# 30   2695109   3100282   3418932
# 31   2695109   3100282   3418932
# 32   5458664   5842594   5941653
# 33   5458664   5842594   5941653
# 34   4461688   4726184   4921285
# 35   4461688   4726184   4921285
#
#                                        Indicator        2005_y        2010_y  \
# 0   Personal remittances, received (current US$)  0.000000e+00  3.462515e+08
# 1                              GDP (current US$)  6.209140e+09  1.585657e+10
# 2   Personal remittances, received (current US$)  4.642385e+09  1.085021e+10
# 3                              GDP (current US$)  6.944294e+10  1.150000e+11
# 4   Personal remittances, received (current US$)  3.337062e+09  1.363604e+10
# 5                              GDP (current US$)  2.290000e+12  6.090000e+12
# 6   Personal remittances, received (current US$)  6.865779e+09  1.279163e+10
# 7                              GDP (current US$)  2.860000e+12  3.420000e+12
# 8   Personal remittances, received (current US$)  2.212509e+10  5.347996e+10
# 9                              GDP (current US$)  8.200000e+11  1.680000e+12
# 10  Personal remittances, received (current US$)  5.419621e+09  6.916051e+09
# 11                             GDP (current US$)  2.860000e+11  7.550000e+11
# 12  Personal remittances, received (current US$)  4.093519e+09  7.977048e+09
# 13                             GDP (current US$)  1.850000e+12  2.130000e+12
# 14  Personal remittances, received (current US$)  6.202192e+07  2.255562e+08
# 15                             GDP (current US$)  5.712367e+10  1.480000e+11
# 16  Personal remittances, received (current US$)  2.274184e+10  2.208026e+10
# 17                             GDP (current US$)  8.770000e+11  1.060000e+12
# 18  Personal remittances, received (current US$)  4.280000e+09  9.690000e+09
# 19                             GDP (current US$)  1.100000e+11  1.770000e+11
# 20  Personal remittances, received (current US$)  1.373256e+10  2.155663e+10
# 21                             GDP (current US$)  1.030000e+11  2.000000e+11
# 22  Personal remittances, received (current US$)  6.471000e+09  7.659000e+09
# 23                             GDP (current US$)  3.060000e+11  4.790000e+11
# 24  Personal remittances, received (current US$)  9.517833e+08  6.413866e+08
# 25                             GDP (current US$)  9.845279e+10  1.660000e+11
# 26  Personal remittances, received (current US$)  3.436560e+09  5.250020e+09
# 27                             GDP (current US$)  7.640000e+11  1.520000e+12
# 28  Personal remittances, received (current US$)  8.230000e+08  1.622539e+09
# 29                             GDP (current US$)  2.885897e+10  0.000000e+00
# 30  Personal remittances, received (current US$)  1.368000e+09  1.819000e+09
# 31                             GDP (current US$)  5.010000e+11  7.720000e+11
# 32  Personal remittances, received (current US$)  2.408000e+09  6.535000e+09
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-667cace2d69b> in <module>
# ----> 1 ytick = np.arange(220000000000,32620000000000,6480000000000)
#
# NameError: name 'np' is not defined

# %%
# personal remittances and number of migrants for Least developed contries for timed series
x_axis = plot_data_df.columns[3:7]
y_axis = plot_data_df.loc[(plot_data_df["Indicator"] == "Personal remittances, received (current US$)") &
                          (plot_data_df["Income Range"] == "Lower-middle-income")].iloc[:,8:12].sum()
y2_axis = plot_data_df.loc[(plot_data_df["Indicator"] == "GDP (current US$)") &
                          (plot_data_df["Income Range"] == "Lower-middle-income")].iloc[:,8:12].sum()
my_axis = plot_data_df.loc[(plot_data_df["Indicator"] == "GDP (current US$)") &
                          (plot_data_df["Income Range"] == "Lower-middle-income")].iloc[:,3:7].sum()

# #fig, (ax1, ax2) = plt.subplots(2, 1,figsize=(11,6), sharex=True)
fig, ax1 = plt.subplots(figsize=(11,6))

ax3 = ax1.twinx()
ax1.bar(x_axis, y_axis, color='b', alpha=0.5, align="center")
ax1.bar(x_axis, y2_axis, color='g', alpha=0.5, align="center")
ax3.plot(x_axis, my_axis, linestyle=':', linewidth=1, marker="o", color="red")

ax1.set_xlabel('Years')
ax1.set_ylabel('Money', color='b')
ax3.set_ylabel('Tot Migrants', color='r')

# # # Example line or bar
# # plt.figure(figsize=(13,6))
# # plt.plot(x_axis, y_axis, linestyle=':', linewidth=1, marker="o", color="red", secondary_y=True)
# # plt.bar(x_axis, y2_axis, color='r', alpha=0.5, align="center")

plt.title("Remittances of Least Developed Countries")

plt.tight_layout()
plt.show()

# We might need to add % of GDP value as a label to give a more accurate view and add the 
# number of migrants in each plot point

# %%
# data for bubble

color_list = []

x_axis = plot_data_df.loc[plot_data_df["Indicator"] == "GDP (current US$)"]["Tot Indic"]
y_axis = plot_data_df.loc[plot_data_df["Indicator"] == "Personal remittances, received (current US$)"]["Tot Indic"]
z_axis = plot_data_df.loc[plot_data_df["Indicator"] == "GDP (current US$)"]["Tot Migrant"]
labels = plot_data_df.loc[plot_data_df["Indicator"] == "GDP (current US$)"]["Origin"]

# Example bubble
plt.figure(figsize=(13,6))
rur_hdl = plt.scatter(x_axis,y_axis, s=z_axis/20000, alpha=0.85, \
                     marker="o", color="yellow", linewidths=1, label=labels.values)
leg_hdl = plt.legend(handles=[rur_hdl], loc="best", title="Countries Origin")

plt.title("Total GDP, Personal Remittances, No. of Migrants",{"fontname":"Arial","fontsize":18})
plt.xlabel("Total GDP (Billions US$)")
plt.ylabel("Personal Remittances (Billions US$)")

plt.tight_layout()
plt.show()

# %%
# y_axis = plot_data_df.loc[plot_data_df["Indicator"] == "Personal remittances, received (current US$)"]["Tot Indic"]
# y2_axis = plot_data_df.loc[plot_data_df["Indicator"] == "Personal remittances, received (current US$)"].iloc[:,3:7]

# xGDP_axis = plot_data_df.loc[plot_data_df["Indicator"] == "GDP (current US$)"]["Origin"]
# yGDP_axis = plot_data_df.loc[plot_data_df["Indicator"] == "GDP (current US$)"]["Tot Indic"]

# %%
ytick = np.arange(220000000000,32620000000000,6480000000000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-667cace2d69b> in <module>
# ----> 1 ytick = np.arange(220000000000,32620000000000,6480000000000)
#
# NameError: name 'np' is not defined
