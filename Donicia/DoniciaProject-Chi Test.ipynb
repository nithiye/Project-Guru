# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as stats

country_data = "../Output/Data_for_plotting.csv"

mig_data = pd.read_csv(country_data)

mig_data2 = pd.DataFrame(mig_data)

mig_data2.head()
# Out:
#         Origin        Dev Level         Income Range   2005_x   2010_x  \
# 0  Afghanistan  Least developed           Low-income  3826255  4989209
# 1  Afghanistan  Least developed           Low-income  3826255  4989209
# 2   Bangladesh  Least developed  Lower-middle-income  5765158  6742845
# 3   Bangladesh  Least developed  Lower-middle-income  5765158  6742845
# 4        China   Less Developed  Upper-middle-income  7242306  8648435
#
#     2015_x   2017_x                                     Indicator  \
# 0  4855376  4826464  Personal remittances, received (current US$)
# 1  4855376  4826464                             GDP (current US$)
# 2  7246726  7499919  Personal remittances, received (current US$)
# 3  7246726  7499919                             GDP (current US$)
# 4  9674720  9961559  Personal remittances, received (current US$)
#
#          2005_y        2010_y        2015_y        2017_y
# 0  0.000000e+00  3.462515e+08  3.486247e+08  7.343102e+08
# ...

# %%
Cash_Total = mig_data2.iloc[:,7:12].sum(axis=1)
print(Cash_Total)
# Out:
# 0     1.429186e+09
# 1     6.216459e+10
# 2     4.428637e+10
# 3     6.294429e+11
# 4     9.009438e+10
# 5     3.148000e+13
# 6     5.191738e+10
# 7     1.335000e+13
# 8     2.134819e+11
# 9     7.250000e+12
# 10    3.098437e+10
# 11    2.922000e+12
# 12    3.141717e+10
# 13    7.760000e+12
# 14    1.142269e+09
# 15    5.521237e+11
# 16    1.033258e+11
# 17    4.267000e+12
# 18    5.296400e+10
# 19    8.630000e+11
# 20    9.789836e+10
# 21    9.100000e+11
# 22    2.778300e+10
# 23    1.789000e+12
# 24    8.977730e+09
# 25    6.534528e+11
# 26    2.382497e+10
# 27    5.224000e+12
# 28    5.690616e+09
# 29    2.885897e+10
# 30    5.630000e+09
# 31    2.985000e+12
# 32    2.954900e+10
# 33    4.250889e+11
# 34    2.030465e+10
# 35    1.052000e+13
# dtype: float64

# %%
Migrant_Total = mig_data2.iloc[:,3:7].sum(axis=1)
print(Migrant_Total)
# Out:
# 0     18497304
# 1     18497304
# 2     27254648
# 3     27254648
# 4     35527020
# 5     35527020
# 6     15675807
# 7     15675807
# 8     55416860
# 9     55416860
# 10    14409168
# 11    14409168
# 12    11253294
# 13    11253294
# 14    15510433
# 15    15510433
# 16    48741010
# 17    48741010
# 18    20804187
# 19    20804187
# 20    19509515
# 21    19509515
# 22    15722094
# 23    15722094
# 24    12371749
# 25    12371749
# 26    41589224
# 27    41589224
# 28    15044425
# 29    15044425
# 30    11907495
# 31    11907495
# 32    22810405
# 33    22810405
# 34    18249798
# 35    18249798
# dtype: int64

# %%
mig_df["Cash_Total"] = mig_data2.iloc[:,6:10].sum(axis=1)
mig_df
# Out:
#                   Origin    2005_x    2010_x    2015_x    2017_x  \
# 0            Afghanistan   3826255   4989209   4855376   4826464
# 1            Afghanistan   3826255   4989209   4855376   4826464
# 2             Bangladesh   5765158   6742845   7246726   7499919
# 3             Bangladesh   5765158   6742845   7246726   7499919
# 4                  China   7242306   8648435   9674720   9961559
# 5                  China   7242306   8648435   9674720   9961559
# 6                Germany   3585342   3849980   4032528   4207957
# 7                Germany   3585342   3849980   4032528   4207957
# 8                  India   9649626  13320745  15859419  16587070
# 9                  India   9649626  13320745  15859419  16587070
# 10             Indonesia   2714351   3486338   3974691   4233788
# 11             Indonesia   2714351   3486338   3974691   4233788
# 12                 Italy   2739747   2612391   2872011   3029145
# ...

# %%
mig_df["Migrant_Total"] = mig_df.iloc[:,1:5].sum(axis=1)
mig_df
# Out:
#                   Origin    2005_x    2010_x    2015_x    2017_x  \
# 0            Afghanistan   3826255   4989209   4855376   4826464
# 1            Afghanistan   3826255   4989209   4855376   4826464
# 2             Bangladesh   5765158   6742845   7246726   7499919
# 3             Bangladesh   5765158   6742845   7246726   7499919
# 4                  China   7242306   8648435   9674720   9961559
# 5                  China   7242306   8648435   9674720   9961559
# 6                Germany   3585342   3849980   4032528   4207957
# 7                Germany   3585342   3849980   4032528   4207957
# 8                  India   9649626  13320745  15859419  16587070
# 9                  India   9649626  13320745  15859419  16587070
# 10             Indonesia   2714351   3486338   3974691   4233788
# 11             Indonesia   2714351   3486338   3974691   4233788
# 12                 Italy   2739747   2612391   2872011   3029145
# ...

# %%
Personal_R = mig_df.loc[mig_df["Indicator"] == "Personal remittances, received (current US$)"]
GDP = mig_df.loc[mig_df["Indicator"] =="GDP (current US$)"]
GDP
# Out:
#                   Origin    2005_x    2010_x    2015_x    2017_x  \
# 1            Afghanistan   3826255   4989209   4855376   4826464
# 3             Bangladesh   5765158   6742845   7246726   7499919
# 5                  China   7242306   8648435   9674720   9961559
# 7                Germany   3585342   3849980   4032528   4207957
# 9                  India   9649626  13320745  15859419  16587070
# 11             Indonesia   2714351   3486338   3974691   4233788
# 13                 Italy   2739747   2612391   2872011   3029145
# 15            Kazakhstan   3718926   3811293   3905768   4074446
# 17                Mexico  10816544  12413073  12546524  12964869
# 19              Pakistan   3896494   5006753   5922305   5978635
# 21           Philippines   3700591   4704919   5423323   5680682
# 23                Poland   2907295   3855177   4258157   4701465
# 25               Romania   2106961   3274229   3412055   3578504
# ...

# %%
bins = [0, 600, 650, 700, 750]

# %%
group_names = ["<$600", "$600-650", "$650-700", "$700-750"]
group_names

# %%
Scores_School_Spending["Per Student Budget"]=Scores_School_Spending["Per Student Budget"]\
.replace('[\$]','',regex=True).astype('float')

# %%
Scores_School_Spending["Spending Ranges Per Student"] = pd.cut(Scores_School_Spending["Per Student Budget"],bins, labels=group_names)
