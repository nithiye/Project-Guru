# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# %%
# File to read
org_dest_csv = "Resources/UN_MigrantStockByOriginAndDestination_2017.csv"

# Read data into Pandas data frame
org_dest_DF = pd.read_csv(org_dest_csv)

# %%
# we need countries of origin, country of destination, total numbers of migrants, years
org_dest_DF
# Out:
#         Year Major area, region, country or area of destination Afghanistan  \
# 0     1990.0                                              WORLD   6,724,681
# 1     1990.0                             More developed regions     119,338
# 2     1990.0                             Less developed regions   6,605,343
# 3     1990.0                          Least developed countries          ..
# 4     1990.0  Less developed regions, excluding least develo...   6,605,343
# 5     1990.0                              High-income countries     269,865
# 6     1990.0                            Middle-income countries   6,454,816
# 7     1990.0                      Upper-middle-income countries   3,152,582
# 8     1990.0                      Lower-middle-income countries   3,302,234
# 9     1990.0                               Low-income countries          ..
# 10    1990.0                                 Sub-Saharan Africa         123
# ...
